# %% [markdown]
# <a href="https://colab.research.google.com/github/walperju/GoogleCollab/blob/main/NaiveBayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #tratar dados tabulares , ou seja em linhas e colunas
import numpy as np #tratar dados na forma de vetores e matrizes , muito usado para AI
from sklearn.model_selection import train_test_split #usado para dividir em conjunto de treino e conjunto de testes
from sklearn.naive_bayes import GaussianNB #usada para criar o modelo , que no momento é o Naive-Bayes do tipo Gaussian NB
from sklearn.preprocessing import LabelEncoder #usado para codificar os dados, transformar os dados categoricos em numericos para que as bibliotcas sejam capazes de compreender e processar.
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report #contem as metricas usadas para calcular a regressao linear
from yellowbrick.classifier import ConfusionMatrix #usada para gerar a matriz de confusao em classificacoes

# %%
base = pd.read_csv("insurance.csv", keep_default_na=False)
base.head()
# Out:
#    Unnamed: 0  GoodStudent         Age    SocioEcon RiskAversion VehicleYear  \
# 0           1        False       Adult        Prole  Adventurous       Older
# 1           2        False      Senior        Prole     Cautious     Current
# 2           3        False      Senior  UpperMiddle   Psychopath     Current
# 3           4        False  Adolescent       Middle       Normal       Older
# 4           5        False  Adolescent        Prole       Normal       Older
#
#   ThisCarDam RuggedAuto  Accident    MakeModel  ... HomeBase AntiTheft  \
# 0   Moderate   EggShell      Mild      Economy  ...     City     False
# 1       None   Football      None      Economy  ...     City      True
# 2       None   Football      None  FamilySedan  ...     City     False
# 3       None   EggShell      None      Economy  ...   Suburb     False
# 4   Moderate   Football  Moderate      Economy  ...     City     False
#
#    PropCost OtherCarCost  OtherCar   MedCost  Cushioning Airbag   ILiCost  \
# 0   TenThou     Thousand      True  Thousand        Poor  False  Thousand
# 1  Thousand     Thousand      True  Thousand        Good   True  Thousand
# 2  Thousand     Thousand     False  Thousand        Good   True  Thousand
# 3  Thousand     Thousand      True  Thousand        Fair  False  Thousand
# 4   TenThou     Thousand     False  Thousand        Fair  False  Thousand
#
#    DrivHist
# 0      Many
# 1      Zero
# 2       One
# 3      Zero
# 4      Many
#
# [5 rows x 28 columns]

# %%
base = base.drop(columns=['Unnamed: 0'])
base.head()
# Out:
#    GoodStudent         Age    SocioEcon RiskAversion VehicleYear ThisCarDam  \
# 0        False       Adult        Prole  Adventurous       Older   Moderate
# 1        False      Senior        Prole     Cautious     Current       None
# 2        False      Senior  UpperMiddle   Psychopath     Current       None
# 3        False  Adolescent       Middle       Normal       Older       None
# 4        False  Adolescent        Prole       Normal       Older   Moderate
#
#   RuggedAuto  Accident    MakeModel DrivQuality  ... HomeBase  AntiTheft  \
# 0   EggShell      Mild      Economy        Poor  ...     City      False
# 1   Football      None      Economy      Normal  ...     City       True
# 2   Football      None  FamilySedan   Excellent  ...     City      False
# 3   EggShell      None      Economy      Normal  ...   Suburb      False
# 4   Football  Moderate      Economy        Poor  ...     City      False
#
#    PropCost  OtherCarCost OtherCar   MedCost Cushioning Airbag   ILiCost  \
# 0   TenThou      Thousand     True  Thousand       Poor  False  Thousand
# 1  Thousand      Thousand     True  Thousand       Good   True  Thousand
# 2  Thousand      Thousand    False  Thousand       Good   True  Thousand
# 3  Thousand      Thousand     True  Thousand       Fair  False  Thousand
# 4   TenThou      Thousand    False  Thousand       Fair  False  Thousand
#
#   DrivHist
# 0     Many
# 1     Zero
# 2      One
# 3     Zero
# 4     Many
#
# [5 rows x 27 columns]

# %%
base.shape
# Out:
# (20000, 27)

# %%
print(base.isnull().sum())
# Out:
# GoodStudent     0
# Age             0
# SocioEcon       0
# RiskAversion    0
# VehicleYear     0
# ThisCarDam      0
# RuggedAuto      0
# Accident        0
# MakeModel       0
# DrivQuality     0
# Mileage         0
# Antilock        0
# DrivingSkill    0
# SeniorTrain     0
# ThisCarCost     0
# Theft           0
# CarValue        0
# HomeBase        0
# AntiTheft       0
# PropCost        0
# OtherCarCost    0
# OtherCar        0
# MedCost         0
# Cushioning      0
# Airbag          0
# ILiCost         0
# DrivHist        0
# dtype: int64

# %%
Y=base.iloc[:,7].values #coluna acidente que será a nossa classe , portanto y
X=base.drop(base.columns[7], axis=1).values
X
# Out:
# array([[False, 'Adult', 'Prole', ..., False, 'Thousand', 'Many'],
#        [False, 'Senior', 'Prole', ..., True, 'Thousand', 'Zero'],
#        [False, 'Senior', 'UpperMiddle', ..., True, 'Thousand', 'One'],
#        ...,
#        [False, 'Senior', 'UpperMiddle', ..., True, 'Thousand', 'Zero'],
#        [False, 'Adult', 'Middle', ..., True, 'Thousand', 'Zero'],
#        [False, 'Adult', 'Middle', ..., True, 'Thousand', 'Zero']],
#       dtype=object)

# %%
labelencoder = LabelEncoder() #transforma a variavel independente CATEGORICA em uma variavel independente DISCRETA
for i in range(X.shape[1]):
  if X[:,i].dtype == 'object':
    X[:,i] = labelencoder.fit_transform(X[:,i])
X
# Out:
# array([[0, 1, 1, ..., 0, 3, 0],
#        [0, 2, 1, ..., 1, 3, 2],
#        [0, 2, 2, ..., 1, 3, 1],
#        ...,
#        [0, 2, 2, ..., 1, 3, 2],
#        [0, 1, 0, ..., 1, 3, 2],
#        [0, 1, 0, ..., 1, 3, 2]], dtype=object)

# %%
X_treinamento, X_test, Y_treinamento, Y_test = train_test_split(X, Y,test_size=0.3, random_state=12)

# %%
modelo = GaussianNB()
modelo.fit(X_treinamento, Y_treinamento)
# Out:
# GaussianNB()

# %%
previsoes = modelo.predict(X_test) #sempre que usar scikitLearn use o método predict

# %%
previsoes
# Out:
# array(['Moderate', 'Mild', 'Moderate', ..., 'None', 'Mild', 'None'],
#       dtype='<U8')

# %%
accuracy = accuracy_score(Y_test, previsoes) #simplesmente o percentual de acerto
precision = precision_score(Y_test, previsoes, average='weighted')
recall = recall_score(Y_test, previsoes, average='weighted')
f1 = f1_score(Y_test, previsoes, average='weighted')
print(f'Acurácia:{accuracy},Precisão:{precision},Recall:{recall},F1_Score:{f1}')
# Out:
# Acurácia:0.857,Precisão:0.919107010136158,Recall:0.857,F1_Score:0.8343753099843555
