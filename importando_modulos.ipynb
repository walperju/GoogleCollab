# %% [markdown]
# <a href="https://colab.research.google.com/github/walperju/GoogleCollab/blob/main/importando_modulos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Projeto ABC

# %% [markdown]
# ## Importando Bibliotecas

# %%
import pandas as pd

# %%
import numpy as np

# %%
print("Teste texto com Git")
# Out:
# Teste texto com Git

# %% [markdown]
# ### Importando dados

# %%
# rotina de importação
